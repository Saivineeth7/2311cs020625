# %% [markdown]
# <a href="https://colab.research.google.com/github/Saivineeth7/2311cs020625/blob/main/kmeans_clustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import files
uploaded = files.upload()
file_name = list(uploaded.keys())[0]
df = pd.read_csv(file_name)
# Out:
#      <input type="file" id="files-ecfaf9a1-c66d-42da-9fef-890f8572c35b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ecfaf9a1-c66d-42da-9fef-890f8572c35b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df
# Out:
#         Name  Age  Income($)
# 0        Rob   27      70000
# 1    Michael   29      90000
# 2      Mohan   29      61000
# 3     Ismail   28      60000
# 4       Kory   42     150000
# 5     Gautam   39     155000
# 6      David   41     160000
# 7     Andrea   38     162000
# 8       Brad   36     156000
# 9   Angelina   35     130000
# 10    Donald   37     137000
# 11       Tom   26      45000
# 12    Arnold   27      48000
# 13     Jared   28      51000
# 14     Stark   29      49500
# 15    Ranbir   32      53000
# 16    Dipika   40      65000
# 17  Priyanka   41      63000
# 18      Nick   43      64000
# 19      Alia   39      80000
# 20       Sid   41      82000
# 21     Abdul   39      58000

# %%
df.head()
# Out:
#       Name  Age  Income($)
# 0      Rob   27      70000
# 1  Michael   29      90000
# 2    Mohan   29      61000
# 3   Ismail   28      60000
# 4     Kory   42     150000

# %%
# !pip install scikit-learn  # Installs the scikit-learn library if not already installed
import pandas as pd
from google.colab import files
from sklearn.cluster import KMeans # Imports the KMeans class from sklearn.cluster

uploaded = files.upload()
file_name = list(uploaded.keys())[0]
df = pd.read_csv(file_name)

km = KMeans(n_clusters=3)
y_predicted = km.fit(df[['Age','Income($)']])
# Out:
# ...
#      <input type="file" id="files-d4de7230-1a00-443d-8ebd-ef6e4525d3ec" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d4de7230-1a00-443d-8ebd-ef6e4525d3ec">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
km = KMeans(n_clusters=3)
y_predicted = km.fit(df[['Age','Income($)']])
y_predicted
# Out:
# KMeans(n_clusters=3)

# %%
df['cluster']=y_predicted

# %%
km.cluster_centers_
# Out:
# array([[3.24166667e+01, 5.72916667e+04],
#        [3.82857143e+01, 1.50000000e+05],
#        [3.63333333e+01, 8.40000000e+04]])

# %%
# !pip install scikit-learn  # Installs the scikit-learn library if not already installed
import pandas as pd
from google.colab import files
from sklearn.cluster import KMeans # Imports the KMeans class from sklearn.cluster
import matplotlib.pyplot as plt # Imports the pyplot module for plotting, aliased as plt

uploaded = files.upload()
file_name = list(uploaded.keys())[0]
df = pd.read_csv(file_name)

km = KMeans(n_clusters=3)
y_predicted = km.fit(df[['Age','Income($)']])

df['cluster']=y_predicted

df1 = df[df.cluster==0]
df2 = df[df.cluster==1]
df3 = df[df.cluster==2]
plt.scatter(df1.Age,df1['Income($)'],color='green') # Now plt is defined and can be used
plt.scatter(df2.Age,df2['Income($)'],color='red')
plt.scatter(df3.Age,df3['Income($)'],color='black')
plt.scatter(km.cluster_centers_[:,0],km.cluster_centers_[:,1],color='purple',marker='*',label='centroid')
plt.xlabel('Age')
# Out:
# ...
#      <input type="file" id="files-4b07545e-3ef8-43c5-9eae-4d74cc82aec2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4b07545e-3ef8-43c5-9eae-4d74cc82aec2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
